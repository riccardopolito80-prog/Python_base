# %% [markdown]
# # HELLO WORD, IN QUESTO PICCOLO DOCUMENTO HO RACCHIUSO QUELLE CHE SONO LE FUNZIONI BASE DI PYTHON,IMPORTANTE VEDERLE UNA PER UNA E TESTARLA MANO A MANO PER SVILLUPARE AUTONOMIA NEL CODING SEMPLICE, INIZIARE SEMPRE VISUALIZZANDO UNO PSEUDO-CODICE.

# %% [markdown]
# # Esercizio 1 esempio usando .format per integrare più elementi di variabili
# print("hello") #Partiamo con il classico comando print, ma non bisogna tralasciare gli operatori [+addizione,-sott,*molt,**potenza,/divisione(numero decimale as a result),//divisione intera,%modulo(resto divisione)]
#
#
# age=40
# its=30
# fun=30
# print("io per te anni {1} sono tanti".format(age,its,fun))
# # con \n vai a capo e con \t generi tabulazione dopo la t
# # se ti chiedi di che tipo sia l'elemento che stai affrontando esegui print(type("elemento"))

# %% [markdown]
# # Creiamo un range  usando la formula: for (variabile) in (range o variabile definita): Creiamo un ciclo che si ripeterà al fine di soddisfare la richiesta, ricorda che python conta lo 0 come un numero, ecco spiegato perchè da 0 a 10 printerà fino a 9 poichè avraà realizzato il range da 0 a 10 numeri.
# for t in range(1,10):
#     print(t)

# %% [markdown]
# # se vuoi fare una lista a condizioni e variabili fai variabile=valore, nota che non puoi mettere liste o tuple, non li legge mai.
# min=-5
# max=6
# for i in range(min,max):
#     print("numeri del riquadro",i)
# # ancora più avanzata integri if(se) elif(altrimenti se) e else(sennò fai), importanti da integrare quando si vogliono aggiungere più condizioni.
# if i<=0:
#     print("0 rientra neill'insieme")
# elif i>=0:
#     print("Ci sono numeri maggiori di 0")
# else:("sei fuori dall'insieme")
# # importante siccome if sono condizioni sono seguite da Operatori di Confronto (==,<,>,>=,<=,!="significa DIVERSO") oppure AND(altra condizione True ) NOT(non ) OR(una delle due True) da notare che le ultime 3 le affianchi anche ai valori booleani.

# %%
# se vuoi puoi cambiare il range in altro valore purchè rispetti la struttura for 'x' in 'value':
v="Le cicale fanno aeiou"
numeratore=0
for i in v:
    if i=="a":
        numeratore=numeratore+1
print("le parole con la a sono",numeratore)

# da notare come se appena mettiamo print fuori dall'indentazione non verrà ripetuta 3 volte la frase ma solo accolto il range

# %% [markdown]
# # usiamo ora la funzione while che fa riferimento  alle funzioni booleviane , ovvero un ciclo si esegue affinchè la boolevan_var sia true
# n=5
#
# while n<10:
#     print(n)
#
#     n=n+1
#
#
#
# print("la variabile vale",n)

# %%
# creiamo ora liste , sempre seguite da variabile =[] oppure da tuple dunque t=[dove posso ripetere gli elementi]
lista=["marco","giulia","marco"]
print(type(lista))
print(lista)
lista.append("giuliana")
v=(len(lista))
lista.sort()
print(lista)


lista=("marco","giovanni","usala","marco")
print(lista)
print(type(lista))
v=(len(lista))
print(v)
n1,n2,n3,n4=(lista)
print(n1)
# con len vedi lunghezza,variabile.sort() ordini, variabile.append("nome")aggiungi

# %% [markdown]
# # creiamo dizionari,ovvero realtà su cui software farà riferimento e si creano con variabile={} , chiamiamo con print(variabile.get(chiave)) o cancelliamo con del(variabile["chiave"])
# "key":"value"
#
#
# ford= {
#     "age":"18",
#     "engine":"emiv16"
# }
#
#
# print(ford.get("age"))

# %%
Film={
    "attore":"richardson",
    
    "interprete":"claus"
}
print(Film.get("attore"))
# NOTA:FAI ATTENZIONE SEMPRE A , MAIUSCOLE E CHIUDERE PARENTESI 
for x in Film.get("attore"):
    print(x,"lui è uno degli attori mentre interprete è" Film.get("interprete"))
    
print("\t",x, "questi sono gli attori")
         # possiamo usare anche for x in range per le liste
# con le liste o vari set tipo x1 o x2 possiamo fare x1.intersection(x2)per elementi analoghi, per unirli ,allo stesso ordine .union(),.issubset() per sottoinsiemi , .add() per aggiungere elemento, e .remove() per rimuovere.

# %% [markdown]
# alphabeto="aeiuojdiwoj"
#
# for i in ("alphabet"):
#     print(i,ord(i))
#     #con ord otteniamo code point in decimale delle lettere mentre con chr il contrario
#
#
#
# print(97,chr(97)) #difatti ci ridà la a dal valore 97
#
# #ora facciamo encoding u("frase") e decoding b("frase") e sotto fai .encode("UTF-32") e .decode("UTF-8") gli UTF in base a come ti servono
#
# ilaz=u"che bella giornata"
# print(ilaz.encode("UTF-32"))
# print(len(ilaz.encode("UTF-32")))

# %%
 #come creare funzioni fai def(): seguito dalla funzione che per ora sarà print , permette di risparmiare righe di codice tramite invocazione 
def funzione_prova():
    return(4)
    print("test funziona")

funzione_prova()
    
#hai digitato esattamente tutto quello dopo def per chiamarla e quello dopo : definisce la funzione ovvero cosa accadrà
def sum(a,b):
    return a+b


sum(6,4)
# in def all'assegnazione di valori puoi assegnare input specifici come a=7 o b=8
# Out:
# 10

# %% [markdown]
# # come creare file o aprire file ? fai variabile=open("file name", mode="r") e mode scegli se r lettura,w scrittura, x creazione+scrittura, + b binaria o t testuale. Logicamente se crei usa x , se devi modificare esistente premi w.
# with open("example",mode="w") as file:
#     file.write("HELLO")
#     #c=file.read(0)#definisci quanto vuoi leggere del file, se mettessi rb leggeresti decodificato binariarmente.
#     file.seek(0) #sposti il puntatore nella posizione dove vuoi
#     file.write("richard,come stai?") #avrai scritto sul file richard

# %%
# list comprienshon ha una formula per fare di una lista intera il range siccome prima facevamo per singola variabile

y=[1,3,4,5,6,7]
burga=[item**2 for item in y if item>=0] # crei lista poi crei variabile e applichi formula =[item(operazione) for item in (lista) puoi aggiungere if]
print(burga) # puoi farlo anche per funzioni integrando if e not and nella stringa[]
# Out:
# [1, 9, 16, 25, 36, 49]

# %% [markdown]
# # serializzazione json
# import json
#
# d={
#     "motore":"v6",
#     "marca":"ep8",
#     "gioco":"v3"
# }
# filename="example/json_dump.json"
# with open(filename, "w") as f:
#     json.dump(d, f)  # questa è la formula per creare un file che abbia formato json (dump) lo usi per dizionari complessi (dumps)per stringhe e in quel caso o quando necessario alla formula aggiungi indent=numero e sort_keys=true se vuoi tutto ordinato ad esempio,con  questo
#     possiamo anche fare da stringa a oggetto usando load o loads, se non riesce a leggerle facciamo import json from JSONEncoder
#
# # Pickle è la stessa identica cosa e usa gli stessi comandi , meglio JSON poichè può interagire con tutti però in casi specifici come il machine learning si fa riferimento a pickle.
